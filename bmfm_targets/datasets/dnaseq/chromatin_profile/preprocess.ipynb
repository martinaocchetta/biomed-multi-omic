# %% [markdown]
# ### This is for preprocessing the genalm_deepsea file...

# %%
sed 1d train.csv > train_woheader.csv
awk -F"," '{print $1}' train_woheader.csv > train_chunk.csv

# %%
python bmfm_targets/datasets/SNPdb/snp_data_splitter.py 
    -i /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000 
    -in_name train_chunk.csv  -o /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/parquet/train -tr 1.0 -cs 50000


python bmfm_targets/datasets/dnaseq/chromatin_profile/data_parquet_splitter.py -i /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000 -in_name dev_woheader.csv -o /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/parquet/dev_woheader

python bmfm_targets/datasets/dnaseq/chromatin_profile/data_parquet_splitter.py -i /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000 -in_name dev_test.csv -o /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/parquet/dev_test

python bmfm_targets/datasets/dnaseq/chromatin_profile/data_parquet_splitter.py -i /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000 -in_name  train_woheader.csv -o /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/parquet/train_woheader -cs 50000
python bmfm_targets/datasets/dnaseq/chromatin_profile/data_parquet_splitter.py -i /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000 -in_name  test_woheader.csv -o /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/parquet/test_woheader -cs 50000

# %%
python -m bmfm_targets.datasets.data_conversion.parquet2litdata -i /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/parquet/dev_test/ -o /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/litdata/dev_test --tokenizer bmfm_targets/tokenization/snp_vocab/tokenizers/dna_chunks --chromatin --no-splits
python -m bmfm_targets.datasets.data_conversion.parquet2litdata -i /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/parquet/test_test/ -o /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/litdata/test_test --tokenizer bmfm_targets/tokenization/snp_vocab/tokenizers/dna_chunks --chromatin --no-splits
python -m bmfm_targets.datasets.data_conversion.parquet2litdata -i /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/parquet/train_test/ -o /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/litdata/train_test --tokenizer bmfm_targets/tokenization/snp_vocab/tokenizers/dna_chunks --chromatin --no-splits

python -m bmfm_targets.datasets.data_conversion.parquet2litdata -i /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/parquet/dev_woheader -o /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/litdata/dev_woheader --tokenizer bmfm_targets/tokenization/snp_vocab/tokenizers/dna_chunks --chromatin --no-splits
python -m bmfm_targets.datasets.data_conversion.parquet2litdata -i /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/parquet/train_woheader -o /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/litdata/train_woheader --tokenizer bmfm_targets/tokenization/snp_vocab/tokenizers/dna_chunks --chromatin --no-splits
python -m bmfm_targets.datasets.data_conversion.parquet2litdata -i /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/parquet/test_woheader -o /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/litdata/test_woheader --tokenizer bmfm_targets/tokenization/snp_vocab/tokenizers/dna_chunks --chromatin --no-splits
# Out:
#   Cell In[2], line 1
#     python -m bmfm_targets.datasets.data_conversion.parquet2litdata -i /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/parquet/dev_test/ -o /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/litdata/dev_test --tokenizer bmfm_targets/tokenization/snp_vocab/tokenizers/dna_chunks --chromatin --no-splits
#               ^
# SyntaxError: invalid syntax

# %%
# Found a bug that the int was not serialized with list... 
# new command

jbsub -cores 12+1  -mem 60g -q x86_24h  -name litdata python -m bmfm_targets.datasets.data_conversion.parquet2litdata  -i /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/parquet/train -o /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/litdata/train1 --tokenizer bmf
m_targets/tokenization/snp_vocab/tokenizers/dna_chunks --chromatin --no-splits

jbsub -cores 12+1  -mem 60g -q x86_12h -name train python -m bmfm_targets.datasets.data_conversion.parquet2litdata -i /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/parquet/train_woheader -o /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/litdata/train_woheader --tokenizer bmfm_targets/tokenization/snp_vocab/tokenizers/dna_chunks --chromatin --no-splits
jbsub -cores 12+1  -mem 60g -q x86_12h -name train python -m bmfm_targets.datasets.data_conversion.parquet2litdata -i /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/parquet/test_woheader -o /dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/litdata/test_woheader --tokenizer bmfm_targets/tokenization/snp_vocab/tokenizers/dna_chunks --chromatin --no-splits

# %%
#create the label dict...
col_names = ['dnase_'+ str(i) for i in range(125)] + ['tf_' + str(i) for i in range(125,815)] + [ 'histone_' + str(i) for i in range(815,919)]

label_values = {"0": 0, "1": 1}

label_dict = [{"label_name":col, "label_values":label_values} for col in col_names]

print(label_dict)

import json

with open("chromatin_profile_all_labels.json", "w") as outfile:
    json.dump(label_dict, outfile)

# for item in all_labels_dict:
#     if label_column_name == item["label_name"]:
#         return item["label_values"]
# Out:
# [{'label_name': 'dnase_0', 'label_values': {'0': 0, '1': 1}}, {'label_name': 'dnase_1', 'label_values': {'0': 0, '1': 1}}, {'label_name': 'dnase_2', 'label_values': {'0': 0, '1': 1}}, {'label_name': 'dnase_3', 'label_values': {'0': 0, '1': 1}}, {'label_name': 'dnase_4', 'label_values': {'0': 0, '1': 1}}, {'label_name': 'dnase_5', 'label_values': {'0': 0, '1': 1}}, {'label_name': 'dnase_6', 'label_values': {'0': 0, '1': 1}}, {'label_name': 'dnase_7', 'label_values': {'0': 0, '1': 1}}, {'label_name': 'dnase_8', 'label_values': {'0': 0, '1': 1}}, {'label_name': 'dnase_9', 'label_values': {'0': 0, '1': 1}}, {'label_name': 'dnase_10', 'label_values': {'0': 0, '1': 1}}, {'label_name': 'dnase_11', 'label_values': {'0': 0, '1': 1}}, {'label_name': 'dnase_12', 'label_values': {'0': 0, '1': 1}}, {'label_name': 'dnase_13', 'label_values': {'0': 0, '1': 1}}, {'label_name': 'dnase_14', 'label_values': {'0': 0, '1': 1}}, {'label_name': 'dnase_15', 'label_values': {'0': 0, '1': 1}}, {'label_name': 
# ...

# %%
from bmfm_targets.datasets.dnaseq import StreamingDNASeqChromatinProfileDataset
path0 = '/dccstor/bmfm-targets1/data/omics/genome/finetune_datasets/chromatin_profile_prediction/len_1000/litdata'
dataset = StreamingDNASeqChromatinProfileDataset(path0, split='test_test')
count = 0
for index,mfi in enumerate(dataset):
  tokens = mfi.data['dna_chunks']
  count = count + 1
  print(tokens, mfi.metadata)

print(count)
